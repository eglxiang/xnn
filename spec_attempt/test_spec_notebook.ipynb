# %% [markdown]
#     o   o o   o o   o
#      \ /  |\  | |\  |
#       O   | \ | | \ |
#      / \  |  \| |  \|
#     o   o o   o o   o

# %% [markdown]
# ###     xnn neural network library V 0.1

# %% [markdown]
#     explore!
#         experiment!
#             express!

# %% [markdown]
# ### Specifying, instantiating, and viewing models

# %% [markdown]
# The following shows how to spec models in XNN using an object-oriented syntax. Models are built, instantiated, and serialized in  code below. As a bonus, we visualize each net using pydot!

# %% [markdown]
# First we import a few things required for setting up models:

# %%
from xnn.spec import *
from xnn.spec.layers import *
from xnn.spec.train.trainer import *

# These are just globals for convenience
IMGWIDTH=48
IMGHEIGHT=48
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %% [markdown]
# ### Specifying output channels

# %% [markdown]
# Next we setup some objects that store information about the data to train our net (inputs and outputs). This is a part of data specification. The channels will be used below when we need to specify the loss function for supervised learning and the inputs will be bound to input layer(s).

# %%
aus = ChannelSet(name="someaus", type="action_units", type_weight=.5)
aus.add(Channel("AU1", negative_weight=.7, channel_weight=.4))
aus.add(Channel("AU2", negative_weight=.5, channel_weight=.8))
aus.add(Channel("AU4", negative_weight=.7, channel_weight=.4))

emos = ChannelSet(name="allemotions", type="emotions", type_weight=1.0)
emos.add(Channel("anger", negative_weight=.1, channel_weight=.7))
emos.add(Channel("contempt", negative_weight=.1, channel_weight=.9))

print aus
print emos
# Out:
# <spec.data.channels.ChannelSet object at 0x113165710>
# <spec.data.channels.ChannelSet object at 0x113165790>

# %% [markdown]
# Let's see what a channels structure looks like when serialized to regular python dictionary:

# %%
import pprint
pprint.pprint(aus.to_dict())
# Out:
# {'channels': [{'channel_weight': 0.4, 'name': 'AU1', 'negative_weight': 0.7},
#               {'channel_weight': 0.8, 'name': 'AU2', 'negative_weight': 0.5},
#               {'channel_weight': 0.4, 'name': 'AU4', 'negative_weight': 0.7}],
#  'name': 'someaus',
#  'type': 'action_units',
#  'type_weight': 0.5}

# %% [markdown]
# And, here's what the JSON looks like:

# %%
import json
json.dumps(emos.to_dict(), sort_keys=True)
# Out:
# '{"channels": [{"channel_weight": 0.7, "name": "anger", "negative_weight": 0.1}, {"channel_weight": 0.9, "name": "contempt", "negative_weight": 0.1}], "name": "allemotions", "type": "emotions", "type_weight": 1.0}'

# %% [markdown]
# ## Basic MLP with Softmax outputs

# %% [markdown]
# Now we will show how to specify a basic net. First we have to declare a model, which will store the layer objects. Then we add all the layers, add channels to the model, and configure output layers.

# %%
mlp = Model()
pixels = mlp.add(InputLayer(shape=(BATCHSIZE, IMGDIMS)), name="pixels")
hidden1 = mlp.add(DenseLayer(parent=pixels.name, num_units=100,
                             nonlinearity=rectify()), name="hidden1")
hidden2 = mlp.add(DenseLayer(parent=hidden1.name, num_units=200,
                             nonlinearity=rectify()), name="hidden2")
labels = mlp.add(DenseLayer(parent=hidden2.name, num_units=aus.size(),
                            nonlinearity=softmax()), name="labels")


mlp.add_channel_set(aus)

mlp.bind_output(
    layername=labels.name,
    settings=Output(
        loss=categorical_crossentropy(),
        target=ChannelsTarget(channelsets=[aus])
    )
)

print mlp
# Out:
# <spec.model.Model object at 0x11316c110>

# %% [markdown]
# Now here's what it looks like to serialize the simple MLP as a python dictionary:

# %%
print 'MLP dict representation'
pprint.pprint(mlp.to_dict())
# Out:
# MLP dict representation
# {'channelsets': [{'channels': [{'channel_weight': 0.4,
#                                 'name': 'AU1',
#                                 'negative_weight': 0.7},
#                                {'channel_weight': 0.8,
#                                 'name': 'AU2',
#                                 'negative_weight': 0.5},
#                                {'channel_weight': 0.4,
#                                 'name': 'AU4',
#                                 'negative_weight': 0.7}],
#                   'name': 'someaus',
#                   'type': 'action_units',
#                   'type_weight': 0.5}],
#  'layers': [{'name': 'pixels', 'shape': (128, 2304), 'type': 'InputLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'hidden1',
#              'nonlinearity': {'type': 'rectify'},
#              'num_units': 100,
#              'parent': 'pixels',
#              'type': 'DenseLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'hidden2',
#              'nonlinearity': {'type': 'rectify'},
#              'num_units': 200,
#              'parent': 'hidden1',
#              'type': 'DenseLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'labels',
#              'nonlinearity': {'type': 'softmax'},
#              'num_units': 3,
#              'parent': 'hidden2',
#              'type': 'DenseLayer'}],
#  'outputs': [{'layer_name': 'labels',
#               'loss': {'type': 'categorical_crossentropy'},
#               'runtime_nonlinearity': {'type': 'linear'},
#               'scale': 1.0,
#               'target': {'channelsets': ['someaus'],
#                          'type': 'ChannelsTarget'}}]}

# %% [markdown]
# Now let's convert the spec to an actual Lasagne model and print out what the objects are:

# %%
print 'MLP instantiated representation'
pprint.pprint(mlp.instantiate())
# Out:
# MLP instantiated representation
# [{'layer': <lasagne.layers.base.InputLayer object at 0x113153f90>,
#   'name': 'pixels'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x11318ae90>,
#   'name': 'hidden1'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x11318af50>,
#   'name': 'hidden2'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x113192810>,
#   'name': 'labels',
#   'output_settings': {'loss': <lasagne.objectives.Objective object at 0x11318ae50>,
#                       'runtime_nonlinearity': <function linear at 0x10fa912a8>,
#                       'scale': 1.0,
#                       'target': [<spec.data.channels.ChannelSet object at 0x113165710>]}}]

# %% [markdown]
# ### Net architecture visualization

# %% [markdown]
# Finally, we can draw the network:

# %%
from draw_net.draw_net import *

layers=mlp.instantiate()
draw_to_notebook(layers, verbose=True, output_shape=False)
# Out:
# {'layer': <lasagne.layers.base.InputLayer object at 0x11356c990>, 'name': 'pixels'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x11356cb50>, 'name': 'hidden1'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x11356ca50>, 'name': 'hidden2'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x11356cd90>, 'name': 'labels', 'output_settings': {'runtime_nonlinearity': <function linear at 0x10fa912a8>, 'scale': 1.0, 'target': [<spec.data.channels.ChannelSet object at 0x113165710>], 'loss': <lasagne.objectives.Objective object at 0x113153f90>}}

# %% [markdown]
# # Now for some more examples!

# %% [markdown]
# ## Nonlinear autoencoder

# %%
# -------------------------------------------------------------------- #
# Basic nonlinear autoencoder (without weight-sharing)
# -------------------------------------------------------------------- #
autoencoder = Model()
pixels = autoencoder.add(InputLayer(shape=(BATCHSIZE,IMGDIMS)), name="pixels")
hidden = autoencoder.add(DenseLayer(parent=pixels.name, num_units=100,
                                    nonlinearity=tanh()), name="hidden")
recon = autoencoder.add(DenseLayer(parent=hidden.name, num_units=IMGDIMS,
                                   nonlinearity=linear()), name="recon")

autoencoder.bind_output(
    layername=recon.name,
    settings=Output(
        loss=mse(),
        target=ReconstructionTarget(layer=pixels.name)
    )
)
print '---------------------------------'
print 'Autoencoder dict representation'
pprint.pprint(autoencoder.to_dict())
print 'Autoencoder instantiated representation'
pprint.pprint(autoencoder.instantiate())

# view autoencoder graph

layers=autoencoder.instantiate()
draw_to_notebook(layers, verbose=True, output_shape=False)
# Out:
# ---------------------------------
# Autoencoder dict representation
# {'channelsets': [],
#  'layers': [{'name': 'pixels', 'shape': (128, 2304), 'type': 'InputLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'hidden',
#              'nonlinearity': {'type': 'tanh'},
#              'num_units': 100,
#              'parent': 'pixels',
#              'type': 'DenseLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'recon',
#              'nonlinearity': {'type': 'linear'},
#              'num_units': 2304,
#              'parent': 'hidden',
#              'type': 'DenseLayer'}],
#  'outputs': [{'layer_name': 'recon',
#               'loss': {'type': 'mse'},
#               'runtime_nonlinearity': {'type': 'linear'},
#               'scale': 1.0,
#               'target': {'layer': 'pixels', 'type': 'ReconstructionTarget'}}]}
# Autoencoder instantiated representation
# [{'layer': <lasagne.layers.base.InputLayer object at 0x1136b8ad0>,
#   'name': 'pixels'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x1136b8c90>,
#   'name': 'hidden'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x1136b8a50>,
#   'name': 'recon',
#   'output_settings': {'loss': <lasagne.objectives.Objective object at 0x1136b8d10>,
#                       'runtime_nonlinearity': <function linear at 0x10fa912a8>,
#                       'scale': 1.0,
#                       'target': <lasagne.layers.base.InputLayer object at 0x1136b8ad0>}}]
# {'layer': <lasagne.layers.base.InputLayer object at 0x1136b8a10>, 'name': 'pixels'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x1136b85d0>, 'name': 'hidden'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x1136b8050>, 'name': 'recon', 'output_settings': {'runtime_nonlinearity': <function linear at 0x10fa912a8>, 'scale': 1.0, 'target': <lasagne.layers.base.InputLayer object at 0x1136b8a10>, 'loss': <lasagne.objectives.Objective object at 0x1136b8a50>}}

# %% [markdown]
# ## Jointly trained MLP and autoencoder (share the same hidden layer)

# %%
# -------------------------------------------------------------------- #
# Joint nonlinear autoencoder+mlp (without weight-sharing)
# -------------------------------------------------------------------- #
joint = Model()
pixels = joint.add(InputLayer(shape=(BATCHSIZE,IMGDIMS)), name="pixels")
hid1up = joint.add(DenseLayer(parent=pixels.name, num_units=100,
                              nonlinearity=rectify()), name="hid1up")
encoder = joint.add(DenseLayer(parent=hid1up.name, num_units=100,
                               nonlinearity=rectify()), name="encoder")
hid1down = joint.add(DenseLayer(parent=encoder.name, num_units=100,
                                nonlinearity=rectify()), name="hid1down")
# This is the pixel reconstruction layer
recon = joint.add(DenseLayer(parent=hid1down.name, num_units=IMGDIMS,
                             nonlinearity=linear()), name="recon")
# This is the label layer for supervised learning
labels = joint.add(DenseLayer(parent=encoder.name, num_units=emos.size(),
                              nonlinearity=softmax()), name="labels")

joint.add_channel_set(emos)

# Make the recon layer reconstruct the pixels with .5 scaling of the gradients
joint.bind_output(
    layername=recon.name,
    settings=Output(
        loss=mse(),
        scale=0.5,
        target=ReconstructionTarget(layer=pixels.name)
    )
)

# Make the label layer recognize the labels with full gradients
joint.bind_output(
    layername=labels.name,
    settings=Output(
        loss=categorical_crossentropy(),
        target=ChannelsTarget(channelsets=[emos])
    )
)

print '---------------------------------'
print 'Joint autoencoder+MLP dict representation'
pprint.pprint(joint.to_dict())
print 'Joint autoencoder+MLP instantiated representation'
pprint.pprint(joint.instantiate())

# view joint autoencoder+mlp graph

layers=joint.instantiate()
draw_to_notebook(layers, verbose=True, output_shape=False)
# Out:
# ---------------------------------
# Joint autoencoder+MLP dict representation
# {'channelsets': [{'channels': [{'channel_weight': 0.7,
#                                 'name': 'anger',
#                                 'negative_weight': 0.1},
#                                {'channel_weight': 0.9,
#                                 'name': 'contempt',
#                                 'negative_weight': 0.1}],
#                   'name': 'allemotions',
#                   'type': 'emotions',
#                   'type_weight': 1.0}],
#  'layers': [{'name': 'pixels', 'shape': (128, 2304), 'type': 'InputLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'hid1up',
#              'nonlinearity': {'type': 'rectify'},
#              'num_units': 100,
#              'parent': 'pixels',
#              'type': 'DenseLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'encoder',
#              'nonlinearity': {'type': 'rectify'},
#              'num_units': 100,
#              'parent': 'hid1up',
#              'type': 'DenseLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'hid1down',
#              'nonlinearity': {'type': 'rectify'},
#              'num_units': 100,
#              'parent': 'encoder',
#              'type': 'DenseLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'recon',
#              'nonlinearity': {'type': 'linear'},
#              'num_units': 2304,
#              'parent': 'hid1down',
#              'type': 'DenseLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'labels',
#              'nonlinearity': {'type': 'softmax'},
#              'num_units': 2,
#              'parent': 'encoder',
#              'type': 'DenseLayer'}],
#  'outputs': [{'layer_name': 'recon',
#               'loss': {'type': 'mse'},
#               'runtime_nonlinearity': {'type': 'linear'},
#               'scale': 0.5,
#               'target': {'layer': 'pixels', 'type': 'ReconstructionTarget'}},
#              {'layer_name': 'labels',
#               'loss': {'type': 'categorical_crossentropy'},
#               'runtime_nonlinearity': {'type': 'linear'},
#               'scale': 1.0,
#               'target': {'channelsets': ['allemotions'],
#                          'type': 'ChannelsTarget'}}]}
# Joint autoencoder+MLP instantiated representation
# [{'layer': <lasagne.layers.base.InputLayer object at 0x1139b2690>,
#   'name': 'pixels'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x1139b24d0>,
#   'name': 'hid1up'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x1139b2890>,
#   'name': 'encoder'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x1139b2550>,
#   'name': 'hid1down'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x1139aae50>,
#   'name': 'recon',
#   'output_settings': {'loss': <lasagne.objectives.Objective object at 0x1136b8a90>,
#                       'runtime_nonlinearity': <function linear at 0x10fa912a8>,
#                       'scale': 0.5,
#                       'target': <lasagne.layers.base.InputLayer object at 0x1139b2690>}},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x1136c5a90>,
#   'name': 'labels',
#   'output_settings': {'loss': <lasagne.objectives.Objective object at 0x1136c5a10>,
#                       'runtime_nonlinearity': <function linear at 0x10fa912a8>,
#                       'scale': 1.0,
#                       'target': [<spec.data.channels.ChannelSet object at 0x113165790>]}}]
# {'layer': <lasagne.layers.base.InputLayer object at 0x1139b2390>, 'name': 'pixels'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x1136c5b50>, 'name': 'hid1up'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x1136c5d10>, 'name': 'encoder'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x1136c5f10>, 'name': 'hid1down'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x1136d4150>, 'name': 'recon', 'output_settings': {'runtime_nonlinearity': <function linear at 0x10fa912a8>, 'scale': 0.5, 'target': <lasagne.layers.base.InputLayer object at 0x1139b2390>, 'loss': <lasagne.objectives.Objective object at 0x1139b2550>}}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x1139aab50>, 'name': 'labels', 'output_settings': {'runtime_nonlinearity': <function linear at 0x10fa912a8>, 'scale': 1.0, 'target': [<spec.data.channels.ChannelSet object at 0x113165790>], 'loss': <lasagne.objectives.Objective object at 0x1139b2890>}}

# %% [markdown]
# ## Semi-supervised autoencoder (the encoding contains predicted label units)

# %%
# -------------------------------------------------------------------- #
# Semi-supervised autoencoder (without weight-sharing)
# -------------------------------------------------------------------- #
semi = Model()
pixels = semi.add(
    InputLayer(shape=(BATCHSIZE,IMGDIMS)), name="pixels")
hid1up = semi.add(
    DenseLayer(parent=pixels.name,
               num_units=100,
               nonlinearity=rectify()), name="hid1up")
# Use sigmoid labels (like we do in practice)
labelencoder = semi.add(
    DenseLayer(parent=hid1up.name,
               num_units=emos.size(),
               nonlinearity=sigmoid()), name="labelencoder")
# Make hidden encoder also use sigmoid for consistency
hidencoder = semi.add(
    DenseLayer(parent=hid1up.name,
               num_units=100,
               nonlinearity=sigmoid()), name="hidencoder")
# This is the joint encoder layer with label predictions and hidden units
jointencoder = semi.add(
    ConcatLayer(parents=[labelencoder.name, hidencoder.name]), name="jointencoder")
hid1down = semi.add(
    DenseLayer(parent=jointencoder.name,
               num_units=100,
               nonlinearity=rectify()), name="hid1down")
# This is the pixel reconstruction layer
recon = semi.add(
    DenseLayer(parent=hid1down.name,
               num_units=IMGDIMS,
               nonlinearity=linear()), name="recon")

semi.add_channel_set(emos)

# Make the recon layer reconstruct the pixels
semi.bind_output(
    layername=recon.name,
    settings=Output(
        loss=mse(),
        target=ReconstructionTarget(layer=pixels.name)
    )
)

# Make the label encoder layer recognize the labels
semi.bind_output(
    layername=labelencoder.name,
    settings=Output(
        loss=crossentropy(),
        target=ChannelsTarget(channelsets=[emos])
    )
)

print '---------------------------------'
print 'Semi-supervised autoencoder dict representation'
pprint.pprint(semi.to_dict())
print 'Semi-supervised autoencoder instantiated representation'
pprint.pprint(semi.instantiate())

# view semi-supervised autoencoder graph

layers=semi.instantiate()
draw_to_notebook(layers, verbose=True, output_shape=False)
# Out:
# ---------------------------------
# Semi-supervised autoencoder dict representation
# {'channelsets': [{'channels': [{'channel_weight': 0.7,
#                                 'name': 'anger',
#                                 'negative_weight': 0.1},
#                                {'channel_weight': 0.9,
#                                 'name': 'contempt',
#                                 'negative_weight': 0.1}],
#                   'name': 'allemotions',
#                   'type': 'emotions',
#                   'type_weight': 1.0}],
#  'layers': [{'name': 'pixels', 'shape': (128, 2304), 'type': 'InputLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'hid1up',
#              'nonlinearity': {'type': 'rectify'},
#              'num_units': 100,
#              'parent': 'pixels',
#              'type': 'DenseLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'labelencoder',
#              'nonlinearity': {'type': 'sigmoid'},
#              'num_units': 2,
#              'parent': 'hid1up',
#              'type': 'DenseLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'hidencoder',
#              'nonlinearity': {'type': 'sigmoid'},
#              'num_units': 100,
#              'parent': 'hid1up',
#              'type': 'DenseLayer'},
#             {'axis': 1,
#              'name': 'jointencoder',
#              'parents': ['labelencoder', 'hidencoder'],
#              'type': 'ConcatLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'hid1down',
#              'nonlinearity': {'type': 'rectify'},
#              'num_units': 100,
#              'parent': 'jointencoder',
#              'type': 'DenseLayer'},
#             {'Winit': {'range': (0, 1), 'type': 'Uniform'},
#              'binit': {'type': 'Constant', 'val': 0},
#              'name': 'recon',
#              'nonlinearity': {'type': 'linear'},
#              'num_units': 2304,
#              'parent': 'hid1down',
#              'type': 'DenseLayer'}],
#  'outputs': [{'layer_name': 'labelencoder',
#               'loss': {'type': 'crossentropy'},
#               'runtime_nonlinearity': {'type': 'linear'},
#               'scale': 1.0,
#               'target': {'channelsets': ['allemotions'],
#                          'type': 'ChannelsTarget'}},
#              {'layer_name': 'recon',
#               'loss': {'type': 'mse'},
#               'runtime_nonlinearity': {'type': 'linear'},
#               'scale': 1.0,
#               'target': {'layer': 'pixels', 'type': 'ReconstructionTarget'}}]}
# Semi-supervised autoencoder instantiated representation
# [{'layer': <lasagne.layers.base.InputLayer object at 0x11318ae50>,
#   'name': 'pixels'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x11398e250>,
#   'name': 'hid1up'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x11398e1d0>,
#   'name': 'labelencoder',
#   'output_settings': {'loss': <lasagne.objectives.Objective object at 0x1139a9710>,
#                       'runtime_nonlinearity': <function linear at 0x10fa912a8>,
#                       'scale': 1.0,
#                       'target': [<spec.data.channels.ChannelSet object at 0x113165790>]}},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x11398e090>,
#   'name': 'hidencoder'},
#  {'layer': <lasagne.layers.base.ConcatLayer object at 0x11398e450>,
#   'name': 'jointencoder'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x11398ec90>,
#   'name': 'hid1down'},
#  {'layer': <lasagne.layers.base.DenseLayer object at 0x11398ee90>,
#   'name': 'recon',
#   'output_settings': {'loss': <lasagne.objectives.Objective object at 0x11398e0d0>,
#                       'runtime_nonlinearity': <function linear at 0x10fa912a8>,
#                       'scale': 1.0,
#                       'target': <lasagne.layers.base.InputLayer object at 0x11318ae50>}}]
# {'layer': <lasagne.layers.base.InputLayer object at 0x11398e2d0>, 'name': 'pixels'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x113146f10>, 'name': 'hid1up'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x113998290>, 'name': 'labelencoder', 'output_settings': {'runtime_nonlinearity': <function linear at 0x10fa912a8>, 'scale': 1.0, 'target': [<spec.data.channels.ChannelSet object at 0x113165790>], 'loss': <lasagne.objectives.Objective object at 0x11398ec50>}}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x113998690>, 'name': 'hidencoder'}
# {'layer': <lasagne.layers.base.ConcatLayer object at 0x113998610>, 'name': 'jointencoder'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x1139988d0>, 'name': 'hid1down'}
# {'layer': <lasagne.layers.base.DenseLayer object at 0x113998990>, 'name': 'recon', 'output_settings': {'runtime_nonlinearity': <function linear at 0x10fa912a8>, 'scale': 1.0, 'target': <lasagne.layers.base.InputLayer object at 0x11398e2d0>, 'loss': <lasagne.objectives.Objective object at 0x11318ae50>}}
